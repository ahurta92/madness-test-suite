# %%
import os
import pandas as pd
os.chdir("/home/adrianhurtado/testing/madness-test-suite/high")
from madnessReader import MadnessReader
from madnessReader import ExcitedData
from madnessReader import FrequencyData
from daltonRunner import DaltonRunner
# Out:
# /home/adrianhurtado/testing/madness-test-suite/high

# %%
def excited_results(mol):
    
    f_data=ExcitedData(mol,'hf')
    f_data.plot_density_residuals()
    f_data.plot_bsh_residuals()
    ground,omega_df=f_data.compare_dalton('d-aug-cc-pVQZ')
    print(ground)
    print(omega_df)
def freq_results(mol):
    ff_data=FrequencyData(mol,'hf','dipole')
    #ff_data.plot_density_residuals()
    #ff_data.plot_bsh_residuals()
    #ff_data.polar_df
    ff_data.plot_polar_data('t-aug-cc-pVQZ',['xx','yy','zz'])
    #ground,dal_results,mad_results,diff_df=ff_data.compare_dalton('d-aug-cc-pVQZ')
    #print(ground)
    #print(mad_results)
    #diff_df.set_index('frequencies')[['xx','yy','zz']].plot(title='mad-dalton')

# %%
moldata=FrequencyData('H2O','hf','dipole')
basis_list=['d-aug-cc-pVDZ','d-aug-cc-pVTZ','d-aug-cc-pVQZ']
moldata.compare_polar_basis_list('xx',basis_list)
moldata.compare_polar_basis_list('yy',basis_list)
moldata.compare_polar_basis_list('zz',basis_list)
# Out:
#               d-aug-cc-pVDZ  d-aug-cc-pVTZ  d-aug-cc-pVQZ       MRA
# Frequency
# 0.0                8.466035       8.525102       8.532258  8.531010
# 0.0198666875       8.475112       8.534237       8.541396  8.540600
# 0.039733375        8.502528       8.561827       8.568994  8.568288
# 0.07946675         8.615024       8.675069       8.682265  8.681299
# 0.1589335          9.117205       9.181109       9.188398  9.186816

# %%
# Water
# aug-cc-pvNZ

basis_list=['aug-cc-pVDZ','aug-cc-pVTZ','aug-cc-pVQZ']
d_basis_list=['d-aug-cc-pVDZ','d-aug-cc-pVTZ','d-aug-cc-pVQZ']
def basis_set_results(mol,basis_list):
    moldata=FrequencyData(mol,'hf','dipole')
    
    xx_aug=moldata.compare_polar_basis_list('xx',basis_list)
    yy_aug=moldata.compare_polar_basis_list('yy',basis_list)
    zz_aug=moldata.compare_polar_basis_list('zz',basis_list)
    xx_aug=moldata.compare_diff_basis_list('xx',basis_list)
    yy_aug=moldata.compare_diff_basis_list('yy',basis_list)
    zz_aug=moldata.compare_diff_basis_list('zz',basis_list)
    
    d_xx_aug=moldata.compare_polar_basis_list('xx',d_basis_list)
    d_yy_aug=moldata.compare_polar_basis_list('yy',d_basis_list)
    d_zz_aug=moldata.compare_polar_basis_list('zz',d_basis_list)
    xx_aug=moldata.compare_diff_basis_list('xx',d_basis_list)
    yy_aug=moldata.compare_diff_basis_list('yy',d_basis_list)
    zz_aug=moldata.compare_diff_basis_list('zz',d_basis_list)

# %%
import glob
for mol in glob.glob('molecules/*.mol'):
    name=mol.split('/')[1].split('.')[0]
    try:
        print(name)
        basis_set_results(name,basis_list)
    except:
        print('what happened ',name)
# Out:
# C2H2
# what happened  C2H2
# He
# HF
# what happened  HF
# NH3
# what happened  NH3
# Ne
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:345: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# H2
# HCl
# what happened  HCl
# H2O
# CH4
# BeH2
# Be

# %%
from daltonRunner import DaltonRunner
dalton_reader = DaltonRunner()
ground_dalton, response_dalton = dalton_reader.get_frequency_result('Ne', 'hf', 'dipole', 'aug-cc-pVDZ')

# %%
def create_polar_table(mol,xc,basis_list,xx):
    
    ground_dalton, response_dalton = dalton_reader.get_frequency_result(mol, 'hf', 'dipole', basis_list[0])
    freq=response_dalton['frequencies']
    g_data={}
    xx_data=[]
    for i in range(len(freq)):
        xx_data.append({})
    for basis in basis_list:
        ground_dalton, response_dalton = dalton_reader.get_frequency_result(mol, 'hf', 'dipole', basis)
        for i in range(len(freq)):
            xx_data[i][basis]=response_dalton[xx][i]
        g_data[basis]=ground_dalton['totalEnergy']
    g_df=pd.Series(g_data)
    g_df.name='Total HF Energy'
    names=[]
    for f in freq:
        raw_f = r'{}'.format(str(f)) 
        #names.append(r'$$\alpha_{xx}('+raw_f+r')$$')
        names.append('a('+'{:.3f}'.format(f)+')')
    r_dfs=[]
    for i in range(len(freq)):
        r_dfs.append(pd.Series(xx_data[i]))
        r_dfs[i].name=names[i]
    dalton_df=pd.concat([g_df]+r_dfs,axis=1)

    moldata=FrequencyData(mol,'hf','dipole')
    moldata.polar_df[xx]
    mad_data_e={}
    mad_data_r={}
    mad_data_e['Total HF Energy']=moldata.ground_e['e_tot']

    for i in range(len(names)):
        mad_data_r[names[i]]=moldata.polar_df[xx][i]
    
    mad_data_e=pd.Series(mad_data_e)
    mad_data_r=pd.Series(mad_data_r)
    
    mad_data=pd.concat([mad_data_e,mad_data_r],axis=0)
    mad_data.name='MRA'
    return dalton_df.append(mad_data)
    
    return dalton_df

# %%
create_polar_table('Ne','hf',basis_list,'xx')
create_polar_table('He','hf',basis_list,'xx').iloc[:,1:]
# Out:
#              a(0.000)  a(0.049)  a(0.099)  a(0.198)  a(0.395)
# aug-cc-pVDZ  1.303925  1.306791  1.315466  1.351399  1.518182
# aug-cc-pVTZ  1.315968  1.319136  1.328739  1.368724  1.558825
# aug-cc-pVQZ  1.321550  1.324887  1.335014  1.377334  1.582284
# MRA          1.322330  1.325726  1.336040  1.379292  1.592827

# %%
create_polar_table('H2O','hf',basis_list,'xx').iloc[:,1:]
# Out:
#              a(0.000)  a(0.020)  a(0.040)  a(0.079)  a(0.159)
# aug-cc-pVDZ  7.325093  7.334490  7.362996  7.482065  8.063255
# aug-cc-pVTZ  7.723695  7.733549  7.763425  7.887907  8.488541
# aug-cc-pVQZ  7.847663  7.857854  7.888747  8.017363  8.635463
# MRA          7.901982  7.914240  7.946209  8.079450  8.719504

# %%
def create_data(mol,basis_list):
    
    res_dict={'xx':'density_residualX','yy':'density_residualY','zz':'density_residualZ'}
    
    
    moldata=FrequencyData(mol,'hf','dipole')
    xx=['xx','yy','zz']
    data=[]
    for x in xx:
        data.append(create_polar_table(mol,'hf',basis_list,x))
    average=(data[0]+data[1]+data[2])/3
    
    diff_data=average-average.loc['MRA']
    diff_data=diff_data.drop(index='MRA')
    
    polar_diff=diff_data.drop('Total HF Energy',axis=1)
    
    residuals=moldata.final_density_residuals()
    
    cleanX=residuals['density_residualX'].reset_index().drop('index',axis=1)
    cleanY=residuals['density_residualY'].reset_index().drop('index',axis=1)
    cleanZ=residuals['density_residualZ'].reset_index().drop('index',axis=1)
    
    cleanX.rename(columns={'density_residualX':'MRA density residual'},inplace=True)
    cleanY.rename(columns={'density_residualY':'MRA density residual'},inplace=True)
    cleanZ.rename(columns={'density_residualZ':'MRA density residual'},inplace=True)
    clean=(cleanX+cleanY+cleanZ)/3
    clean.index=polar_diff.T.index
    
    average=average.append(clean.T)
    average.name='Average Polarizability'
    
    
    energy_diff=diff_data['Total HF Energy']
    return average,diff_data,energy_diff,polar_diff

basis_list=['aug-cc-pVDZ','aug-cc-pVTZ','aug-cc-pVQZ']
d_basis_list=['d-aug-cc-pVDZ','d-aug-cc-pVTZ','d-aug-cc-pVQZ']
data,diff_data,energy_diff,polar_diff=create_data('Be',basis_list,)
display(data)
display(diff_data)
display(polar_diff)
display(energy_diff)
# Out:
#                       Total HF Energy   a(0.000)   a(0.011)   a(0.022)  \
# aug-cc-pVDZ                -14.572379  44.913706  45.080233  45.587441
# aug-cc-pVTZ                -14.572875  45.440357  45.615188  46.147978
# aug-cc-pVQZ                -14.572969  45.598622  45.775820  46.315917
# MRA                        -14.572938  45.616728  45.775888  46.337138
# MRA density residual              NaN   0.000002   0.000228   0.001614
#
#                        a(0.044)   a(0.089)
# aug-cc-pVDZ           47.738055  58.900395
# aug-cc-pVTZ           48.411880  60.287363
# aug-cc-pVQZ           48.612406  60.699528
# MRA                   48.654566  60.836933
# MRA density residual   0.000025   0.000071
#              Total HF Energy  a(0.000)  a(0.011)  a(0.022)  a(0.044)  a(0.089)
# aug-cc-pVDZ         0.000559 -0.703022 -0.695655 -0.749698 -0.916511 -1.936538
# aug-cc-pVTZ         0.000062 -0.176371 -0.160700 -0.189160 -0.242686 -0.549570
# aug-cc-pVQZ        -0.000031 -0.018106 -0.000068 -0.021222 -0.042160 -0.137405
#              a(0.000)  a(0.011)  a(0.022)  a(0.044)  a(0.089)
# aug-cc-pVDZ -0.703022 -0.695655 -0.749698 -0.916511 -1.936538
# aug-cc-pVTZ -0.176371 -0.160700 -0.189160 -0.242686 -0.549570
# aug-cc-pVQZ -0.018106 -0.000068 -0.021222 -0.042160 -0.137405
# aug-cc-pVDZ    0.000559
# aug-cc-pVTZ    0.000062
# aug-cc-pVQZ   -0.000031
# Name: Total HF Energy, dtype: float64

# %%
import matplotlib.pyplot as plt

basis_list=['aug-cc-pVDZ','aug-cc-pVTZ','aug-cc-pVQZ','aug-cc-pV5Z','aug-cc-pV6Z']
d_basis_list=['d-aug-cc-pVDZ','d-aug-cc-pVTZ','d-aug-cc-pVQZ','d-aug-cc-pV5Z','d-aug-cc-pV6Z']

def create_polar_diff_plot(mol,basis_list):
    
    
    title=mol
    yl=r' $\Delta\alpha_{avg}$'+r' (MRA - BASIS)'
    
    
    data,diff_data,energy_diff,polar_diff=create_data(mol,basis_list)
    polar_diff.iloc[:,:].plot(marker='o', linestyle='solid')
    plt.axhline(linewidth=2,ls='--',color='k',label="MRA Reference")
    plt.xlabel
    plt.legend(fontsize=12)
    plt.xticks(fontsize=14,rotation = 20)
    plt.title(title,fontsize=20)
    plt.ylabel(yl, fontsize=14)
    save=mol+'-'+basis_list[0]
    save='figures/'+save+'.svg'
    plt.savefig(save)
    
    latex_save=mol+'-'+basis_list[0]
    latex_save='tables/'+latex_save+'.tex'
    data=data.round(decimals=3)
    data.to_latex(latex_save,na_rep=' ')
    
    
    return data

mol_list=['Ne','H2O','H2',]

# %%
print('Paper: Static Polar He: ',1.3222)
d1=create_polar_diff_plot('He',basis_list)
d2=create_polar_diff_plot('He',d_basis_list)
display(d1)
display(d2)
# Out:
# Paper: Static Polar He:  1.3222
#                       Total HF Energy  a(0.000)  a(0.049)  a(0.099)  a(0.198)  \
# aug-cc-pVDZ                    -2.856     1.304     1.307     1.315     1.351
# aug-cc-pVTZ                    -2.861     1.316     1.319     1.329     1.369
# aug-cc-pVQZ                    -2.862     1.322     1.325     1.335     1.377
# aug-cc-pV5Z                    -2.862     1.321     1.325     1.335     1.378
# aug-cc-pV6Z                    -2.862     1.321     1.325     1.335     1.378
# MRA                            -2.862     1.322     1.326     1.336     1.379
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.395)
# aug-cc-pVDZ              1.518
# aug-cc-pVTZ              1.559
# aug-cc-pVQZ              1.582
# aug-cc-pV5Z              1.589
# aug-cc-pV6Z              1.590
# MRA                      1.593
# MRA density residual     0.000
#                       Total HF Energy  a(0.000)  a(0.049)  a(0.099)  a(0.198)  \
# d-aug-cc-pVDZ                  -2.856     1.329     1.332     1.342     1.384
# d-aug-cc-pVTZ                  -2.861     1.324     1.327     1.337     1.380
# d-aug-cc-pVQZ                  -2.862     1.322     1.326     1.336     1.379
# d-aug-cc-pV5Z                  -2.862     1.321     1.324     1.335     1.378
# d-aug-cc-pV6Z                  -2.862     1.321     1.325     1.335     1.378
# MRA                            -2.862     1.322     1.326     1.336     1.379
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.395)
# d-aug-cc-pVDZ            1.589
# d-aug-cc-pVTZ            1.592
# d-aug-cc-pVQZ            1.593
# d-aug-cc-pV5Z            1.592
# d-aug-cc-pV6Z            1.592
# MRA                      1.593
# MRA density residual     0.000

# %%
print('Paper: Static Polar H2: ','not given')
d1=create_polar_diff_plot('H2',basis_list)
d2=create_polar_diff_plot('H2',d_basis_list)
display(d1)
display(d2)
# Out:
# Paper: Static Polar H2:  not given
#                       Total HF Energy  a(0.000)  a(0.029)  a(0.058)  a(0.116)  \
# aug-cc-pVDZ                    -1.129     5.115     5.129     5.173     5.355
# aug-cc-pVTZ                    -1.133     5.240     5.256     5.302     5.498
# aug-cc-pVQZ                    -1.133     5.229     5.244     5.291     5.489
# aug-cc-pV5Z                    -1.134     5.223     5.239     5.286     5.483
# aug-cc-pV6Z                    -1.134     5.223     5.239     5.286     5.483
# MRA                            -1.133     5.230     5.245     5.292     5.490
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.233)
# aug-cc-pVDZ              6.253
# aug-cc-pVTZ              6.472
# aug-cc-pVQZ              6.477
# aug-cc-pV5Z              6.475
# aug-cc-pV6Z              6.476
# MRA                      6.483
# MRA density residual     0.000
#                       Total HF Energy  a(0.000)  a(0.029)  a(0.058)  a(0.116)  \
# d-aug-cc-pVDZ                  -1.129     5.184     5.199     5.246     5.442
# d-aug-cc-pVTZ                  -1.133     5.239     5.254     5.301     5.499
# d-aug-cc-pVQZ                  -1.133     5.226     5.242     5.289     5.486
# d-aug-cc-pV5Z                  -1.134     5.223     5.239     5.285     5.483
# d-aug-cc-pV6Z                  -1.134     5.224     5.240     5.287     5.484
# MRA                            -1.133     5.230     5.245     5.292     5.490
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.233)
# d-aug-cc-pVDZ            6.424
# d-aug-cc-pVTZ            6.494
# d-aug-cc-pVQZ            6.480
# d-aug-cc-pV5Z            6.475
# d-aug-cc-pV6Z            6.476
# MRA                      6.483
# MRA density residual     0.000

# %%
print('Paper: Static Polar Be: ',45.6199)
d1=create_polar_diff_plot('Be',basis_list[0:-2])
d2=create_polar_diff_plot('Be',d_basis_list[0:-2])
display(d1)
display(d2)
# Out:
# Paper: Static Polar Be:  45.6199
#                       Total HF Energy  a(0.000)  a(0.011)  a(0.022)  a(0.044)  \
# aug-cc-pVDZ                   -14.572    44.914    45.080    45.587    47.738
# aug-cc-pVTZ                   -14.573    45.440    45.615    46.148    48.412
# aug-cc-pVQZ                   -14.573    45.599    45.776    46.316    48.612
# MRA                           -14.573    45.617    45.776    46.337    48.655
# MRA density residual              NaN     0.000     0.000     0.002     0.000
#
#                       a(0.089)
# aug-cc-pVDZ             58.900
# aug-cc-pVTZ             60.287
# aug-cc-pVQZ             60.700
# MRA                     60.837
# MRA density residual     0.000
#                       Total HF Energy  a(0.000)  a(0.011)  a(0.022)  a(0.044)  \
# d-aug-cc-pVDZ                 -14.572    44.993    45.160    45.670    47.830
# d-aug-cc-pVTZ                 -14.573    45.447    45.622    46.155    48.421
# d-aug-cc-pVQZ                 -14.573    45.599    45.776    46.317    48.614
# MRA                           -14.573    45.617    45.776    46.337    48.655
# MRA density residual              NaN     0.000     0.000     0.002     0.000
#
#                       a(0.089)
# d-aug-cc-pVDZ           59.050
# d-aug-cc-pVTZ           60.310
# d-aug-cc-pVQZ           60.707
# MRA                     60.837
# MRA density residual     0.000

# %%
print('Paper: Static Polar Ne: ',2.3770)
d1=create_polar_diff_plot('Ne',basis_list)
d2=create_polar_diff_plot('Ne',d_basis_list)
display(d1)
display(d2)
# Out:
# Paper: Static Polar Ne:  2.377
#                       Total HF Energy  a(0.000)  a(0.046)  a(0.092)  a(0.184)  \
# aug-cc-pVDZ                  -128.496     1.832     1.835     1.843     1.877
# aug-cc-pVTZ                  -128.533     2.194     2.197     2.208     2.251
# aug-cc-pVQZ                  -128.544     2.329     2.333     2.345     2.396
# aug-cc-pV5Z                  -128.547     2.363     2.367     2.380     2.435
# aug-cc-pV6Z                  -128.547     2.370     2.374     2.387     2.443
# MRA                          -128.547     2.377     2.381     2.395     2.452
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.369)
# aug-cc-pVDZ              2.044
# aug-cc-pVTZ              2.464
# aug-cc-pVQZ              2.642
# aug-cc-pV5Z              2.701
# aug-cc-pV6Z              2.717
# MRA                      2.736
# MRA density residual     0.000
#                       Total HF Energy  a(0.000)  a(0.046)  a(0.092)  a(0.184)  \
# d-aug-cc-pVDZ                -128.496     2.353     2.358     2.371     2.425
# d-aug-cc-pVTZ                -128.533     2.375     2.379     2.393     2.449
# d-aug-cc-pVQZ                -128.544     2.380     2.384     2.398     2.455
# d-aug-cc-pV5Z                -128.547     2.377     2.382     2.395     2.452
# d-aug-cc-pV6Z                -128.547     2.376     2.381     2.395     2.452
# MRA                          -128.547     2.377     2.381     2.395     2.452
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.369)
# d-aug-cc-pVDZ            2.694
# d-aug-cc-pVTZ            2.729
# d-aug-cc-pVQZ            2.738
# d-aug-cc-pV5Z            2.737
# d-aug-cc-pV6Z            2.736
# MRA                      2.736
# MRA density residual     0.000

# %%
d1=create_polar_diff_plot('H2O',basis_list)
d2=create_polar_diff_plot('H2O',d_basis_list)
display(d1)
display(d2)
# Out:
#                       Total HF Energy  a(0.000)  a(0.020)  a(0.040)  a(0.079)  \
# aug-cc-pVDZ                   -76.041     8.141     8.150     8.175     8.281
# aug-cc-pVTZ                   -76.061     8.428     8.437     8.464     8.575
# aug-cc-pVQZ                   -76.066     8.508     8.518     8.545     8.659
# aug-cc-pV5Z                   -76.067     8.528     8.538     8.566     8.681
# aug-cc-pV6Z                   -76.067     8.536     8.545     8.573     8.689
# MRA                           -76.067     8.542     8.552     8.580     8.697
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.159)
# aug-cc-pVDZ              8.763
# aug-cc-pVTZ              9.079
# aug-cc-pVQZ              9.176
# aug-cc-pV5Z              9.203
# aug-cc-pV6Z              9.214
# MRA                      9.226
# MRA density residual     0.000
#                       Total HF Energy  a(0.000)  a(0.020)  a(0.040)  a(0.079)  \
# d-aug-cc-pVDZ                 -76.042     8.522     8.531     8.559     8.676
# d-aug-cc-pVTZ                 -76.061     8.545     8.554     8.582     8.699
# d-aug-cc-pVQZ                 -76.066     8.544     8.553     8.582     8.698
# d-aug-cc-pV5Z                 -76.067     8.542     8.551     8.579     8.696
# d-aug-cc-pV6Z                 -76.067     8.542     8.551     8.579     8.696
# MRA                           -76.067     8.542     8.552     8.580     8.697
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.159)
# d-aug-cc-pVDZ            9.205
# d-aug-cc-pVTZ            9.229
# d-aug-cc-pVQZ            9.227
# d-aug-cc-pV5Z            9.225
# d-aug-cc-pV6Z            9.225
# MRA                      9.226
# MRA density residual     0.000

# %%
d1=create_polar_diff_plot('BeH2',basis_list[0:-2])
d2=create_polar_diff_plot('BeH2',d_basis_list[0:-2])
display(d1)
display(d2)
# Out:
#                       Total HF Energy  a(0.000)  a(0.016)  a(0.032)  a(0.065)  \
# aug-cc-pVDZ                   -15.768    19.040    19.074    19.177    19.600
# aug-cc-pVTZ                   -15.772    19.017    19.051    19.154    19.579
# aug-cc-pVQZ                   -15.773    19.003    19.037    19.141    19.567
# MRA                           -15.773    19.011    19.045    19.148    19.575
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.130)
# aug-cc-pVDZ             21.527
# aug-cc-pVTZ             21.517
# aug-cc-pVQZ             21.514
# MRA                     21.526
# MRA density residual     0.000
#                       Total HF Energy  a(0.000)  a(0.016)  a(0.032)  a(0.065)  \
# d-aug-cc-pVDZ                 -15.769    19.068    19.102    19.206    19.634
# d-aug-cc-pVTZ                 -15.772    19.025    19.059    19.163    19.590
# d-aug-cc-pVQZ                 -15.773    19.009    19.043    19.147    19.573
# MRA                           -15.773    19.011    19.045    19.148    19.575
# MRA density residual              NaN     0.000     0.000     0.000     0.000
#
#                       a(0.130)
# d-aug-cc-pVDZ           21.590
# d-aug-cc-pVTZ           21.541
# d-aug-cc-pVQZ           21.523
# MRA                     21.526
# MRA density residual     0.000

# %%
d1=create_polar_diff_plot('C2H2',basis_list)
d2=create_polar_diff_plot('C2H2',d_basis_list)
display(d1)
display(d2)
# Out:
# File /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole/freq_C2H2-aug-cc-pVDZ.out not found!
# did not find output file
# Try and run molecule  C2H2
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal C2H2-aug-cc-pVDZ.mol\n\n   Tue May 31 03:42:15 PM EDT 2022\n\n   Calculation: freq_C2H2-aug-cc-pVDZ  (input files: freq.dal and C2H2-aug-cc-pVDZ.mol)\n   PID        : 47656\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole\n   Scratch dir: /media/adrianhurtado/00947d28-056d-4e5c-a97f-98acff79841e/DALTON_scratch_adrianhurtado/freq_C2H2-aug-cc-pVDZ_47656\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_C2H2-aug-cc-pVDZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole\n----------------------------------------------------------\n1 informational messages have been issued by DALTON,\noutput from 'grep -n INFO'  (max 10 lines):\n1044: INFO SIR_INTOPEN, old integral transformation not found as expected, ICASE = 2\n\n   Tue May 31 03:42:15 PM EDT 2022\n   ***************************************** \n" None
# did not find output file
# Try and run molecule  C2H2
# File /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole/freq_C2H2-aug-cc-pVTZ.out not found!
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal C2H2-aug-cc-pVTZ.mol\n\n   Tue May 31 03:42:15 PM EDT 2022\n\n   Calculation: freq_C2H2-aug-cc-pVTZ  (input files: freq.dal and C2H2-aug-cc-pVTZ.mol)\n   PID        : 47713\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole\n   Scratch dir: /media/adrianhurtado/00947d28-056d-4e5c-a97f-98acff79841e/DALTON_scratch_adrianhurtado/freq_C2H2-aug-cc-pVTZ_47713\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_C2H2-aug-cc-pVTZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole\n----------------------------------------------------------\n1 informational messages have been issued by DALTON,\noutput from 'grep -n INFO'  (max 10 lines):\n1294: INFO SIR_INTOPEN, old integral transformation not found as expected, ICASE = 2\n\n   Tue May 31 03:42:17 PM EDT 2022\n   ***************************************** \n" None
# did not find output file
# Try and run molecule  C2H2
# File /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole/freq_C2H2-aug-cc-pVQZ.out not found!
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal C2H2-aug-cc-pVQZ.mol\n\n   Tue May 31 03:42:17 PM EDT 2022\n\n   Calculation: freq_C2H2-aug-cc-pVQZ  (input files: freq.dal and C2H2-aug-cc-pVQZ.mol)\n   PID        : 47776\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole\n   Scratch dir: /media/adrianhurtado/00947d28-056d-4e5c-a97f-98acff79841e/DALTON_scratch_adrianhurtado/freq_C2H2-aug-cc-pVQZ_47776\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_C2H2-aug-cc-pVQZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole\n----------------------------------------------------------\n1 informational messages have been issued by DALTON,\noutput from 'grep -n INFO'  (max 10 lines):\n1593: INFO SIR_INTOPEN, old integral transformation not found as expected, ICASE = 2\n\n   Tue May 31 03:42:28 PM EDT 2022\n   ***************************************** \n" None
# did not find output file
# Try and run molecule  C2H2
# File /home/adrianhurtado/testing/madness-test-suite/high/dalton/hf/C2H2/dipole/freq_C2H2-aug-cc-pV5Z.out not found!

# %%
d1=create_polar_diff_plot('CH4',basis_list)
d2=create_polar_diff_plot('CH4',d_basis_list)
display(d1)
display(d2)

# %%
d1=create_polar_diff_plot('HCl',basis_list)
d2=create_polar_diff_plot('HCl',d_basis_list)
display(d1)
display(d2)

# %%
d1=create_polar_diff_plot('HF',basis_list)
d2=create_polar_diff_plot('HF',d_basis_list)
display(d1)
display(d2)

# %%
d1=create_polar_diff_plot('NH3',basis_list)
d2=create_polar_diff_plot('NH3',d_basis_list)
display(d1)
display(d2)
