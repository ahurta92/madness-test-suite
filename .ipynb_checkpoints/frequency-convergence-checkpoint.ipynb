# %%
import os
import pandas as pd
snmem="/gpfs/scratch/ahurtado/large_polar_low"
ahurt="/home/adrianhurtado/testing/madness-test-suite/large_polar_low/"
os.chdir(ahurt)
from madnessReader import MadnessReader
from madnessReader import ExcitedData
from madnessReader import FrequencyData
from madnessReader import *
from daltonRunner import DaltonRunner
import matplotlib.pyplot as plt
dalton_reader = DaltonRunner()
dalton_reader.Np=4
# Out:
# 4

# %%
basis_list=['aug-cc-pVDZ','aug-cc-pVTZ','aug-cc-pVQZ','aug-cc-pV5Z','aug-cc-pV6Z']
d_basis_list=['d-aug-cc-pVDZ','d-aug-cc-pVTZ','d-aug-cc-pVQZ','d-aug-cc-pV5Z','d-aug-cc-pV6Z']

# %%
#excluded=['C6H6']
#b=create_excited_comparison_data('d-aug-cc-pVQZ',excluded)
#display(b)

# %%
import json
converged=[]
not_converged=[]
not_found=[]
json_error=[]
for g in glob.glob('molecules/*.mol'):
    m = g.split('/')
    mol = m[1].split('.')[0]
    try:
        ben=FrequencyData(mol,'hf','dipole')
        if ben.converged.all():
            converged.append(mol)
        else:
            not_converged.append(mol)
    except FileNotFoundError as f:
        print(mol,f)
        not_found.append(mol)
    except json.decoder.JSONDecodeError as j:
        json_error.append(mol)
        print(mol,j)
# Out:
# CSO [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/CSO/calc_info.json'
# LiH Expecting value: line 1 column 1 (char 0)
# OCl2 [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/OCl2/calc_info.json'
# LiH_s Expecting value: line 1 column 1 (char 0)
# SH2 Expecting value: line 1 column 1 (char 0)
# P2 [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/P2/calc_info.json'
# NaCN Expecting value: line 1 column 1 (char 0)
# Na2 Expecting value: line 1 column 1 (char 0)
# N2 Expecting value: line 1 column 1 (char 0)
# SiH4 Expecting value: line 1 column 1 (char 0)
# N2H2 Expecting value: line 1 column 1 (char 0)
# NH3 Expecting value: line 1 column 1 (char 0)
# Mg2 Expecting value: line 1 column 1 (char 0)
# N2H4 Expecting value: line 1 column 1 (char 0)
# Ne Expecting value: line 1 column 1 (char 0)
# SF2 [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/SF2/calc_info.json'
# SiH3F Expecting value: line 1 column 1 (char 0)
# Mg Expecting value: line 1 column 1 (char 0)
# SiO Expecting value: line 1 column 1 (char 0)
# FNO [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/FNO/calc_info.json'
# S2H2 [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/S2H2/calc_info.json'
# LiCl Expecting value: line 1 column 1 (char 0)
# PH3O Expecting value: line 1 column 1 (char 0)
# O3 Expecting value: line 1 column 1 (char 0)
# Cl2 [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/Cl2/calc_info.json'
# NH2Cl Expecting value: line 1 column 1 (char 0)
# LiBH4 Expecting value: line 1 column 1 (char 0)
# CO2 [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/CO2/dipole_hf_0-021097/response_base.json'
# PH3 Expecting value: line 1 column 1 (char 0)
# NaLi Expecting value: line 1 column 1 (char 0)
# SCl2 [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/SCl2/calc_info.json'
# NH2OH Expecting value: line 1 column 1 (char 0)
# NaH Expecting value: line 1 column 1 (char 0)
# NH2F Expecting value: line 1 column 1 (char 0)
# NOCl [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/NOCl/calc_info.json'

# %%
num_c=len(converged)
num_n=len(not_converged)
num_nf=len(not_found)
num_json_e=len(json_error)

total=num_c+num_n+num_nf+num_json_e
print("converged : ",num_c)
print("not converged : ",num_n)
print("not found : ",num_nf)
print("json error : ",num_json_e)
print("total : ",total)
# Out:
# converged :  20
# not converged :  35
# not found :  10
# json error :  25
# total :  90

# %%
converged
# Out:
# ['Li2',
#  'NaCl',
#  'C2H2',
#  'BH3',
#  'CH3OH',
#  'HBS',
#  'CH3NH2',
#  'He',
#  'HF',
#  'H2',
#  'HCl',
#  'CH2BH',
#  'CH3BH2',
#  'H2O',
#  'Ar',
#  'C6H6',
#  'CH4',
#  'BeH2',
#  'BH2F',
#  'Be']

# %%
naughty_list='" "'.join(not_converged)
not_there_list='" "'.join(not_found)
display(not_there_list)
# Out:
# 'CSO" "OCl2" "P2" "SF2" "FNO" "S2H2" "Cl2" "CO2" "SCl2" "NOCl'

# %%
if False:
    for mol in not_converged:
        print(mol)
        d=display_convergence_plots(mol,'hf','dipole',False)

# %%
d=display_convergence_plots('P2','hf','dipole',False)
#create_polar_diff_plot('P2',d_basis_list[0:3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 d=display_convergence_plots('P2','hf','dipole',False)
#
# File ~/testing/madness-test-suite/madness-test-suite/madnessReader.py:688, in display_convergence_plots(mol, xc, rtype, save)
#     686     d = ExcitedData(mol, xc)
#     687 elif rtype == 'dipole':
# --> 688     d = FrequencyData(mol, xc, 'dipole')
#     689 xkeys = []
#     690 ykeys = []
#
# File ~/testing/madness-test-suite/madness-test-suite/madnessReader.py:354, in FrequencyData.__init__(self, mol, xc, operator)
#     351 self.operator = operator
#     352 mad_reader = MadnessReader()
# --> 354 self.ground_params, self.ground_scf_data, self.ground_timing = mad_reader.get_ground_scf_data(mol, xc)
#     355 e_name_list = ['e_coulomb', 'e_kinetic', 'e_local', 'e_nrep', 'e_tot']
#     356 self.ground_e = {}
#
# File ~/testing/madness-test-suite/madness-test-suite/madnessReader.py:147, in MadnessReader.get_ground_scf_data(self, mol, xc)
#     145 def get_ground_scf_data(self, mol, xc):
# --> 147     j = self.__open_ground_json(mol, xc)
#     149     params = j['parameters']
#     150     scf_e_data = j['scf_e_data']
#
# File ~/testing/madness-test-suite/madness-test-suite/madnessReader.py:140, in MadnessReader.__open_ground_json(self, mol, xc)
#     137 path = '/'.join([moldir, jsonf])
#     138 # print("mad_path",path)
# --> 140 with open(path) as json_file:
#     141     response_j = json.loads(json_file.read())
#     143 return response_j
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/adrianhurtado/testing/madness-test-suite/large_polar_low/hf/P2/calc_info.json'

# %%
display(naughty_list)
# Out:
# 'FCN" "P2H4" "HCONH2" "CH3SH" "BH2Cl" "HCN" "C2H4" "SO2" "HNC" "F2" "HOF" "OF2" "ClF" "HCOOH" "CH3Cl" "HCHO" "SiH3Cl" "HOCl" "HOOH" "HCCF" "BF" "BHF2" "HNS" "HBO" "LiCN" "CO" "CS" "CH2NH" "CH3F" "ClCN" "HCHS" "HCCCl" "HNO" "HCP'

# %%
e28='" "'.join(json_error[0:8])
e24='" "'.join(json_error[8:14])
l28='" "'.join(json_error[14:20])
l24='" "'.join(json_error[20:26])

# %%
e28
# Out:
# 'LiH" "LiH_s" "SH2" "NaCN" "Na2" "N2" "SiH4" "N2H2'

# %%
e24
# Out:
# 'NH3O" "NH3" "Mg2" "N2H4" "Ne" "SiH3F'

# %%
l28
# Out:
# 'Mg" "SiO" "LiCl" "PH3O" "O3" "NH2Cl'

# %%
l24
# Out:
# 'LiBH4" "PH3" "NaLi" "NH2OH" "NaH" "NH2F'

# %%
not_converged
# Out:
# ['FCN',
#  'P2H4',
#  'HCONH2',
#  'CH3SH',
#  'BH2Cl',
#  'HCN',
#  'C2H4',
#  'SO2',
#  'HNC',
#  'F2',
#  'HOF',
#  'OF2',
#  'ClF',
#  'HCOOH',
#  'CH3Cl',
#  'HCHO',
#  'SiH3Cl',
#  'HOCl',
#  'HOOH',
#  'HCCF',
#  'BF',
#  'BHF2',
#  'HNS',
#  'HBO',
#  'LiCN',
#  'CO',
#  'CS',
#  'CH2NH',
#  'CH3F',
#  'ClCN',
#  'HCHS',
#  'HCCCl',
#  'HNO',
#  'HCP']

# %%
display(len(not_converged))
display(not_converged)
# Out:
# 34
# ['FCN',
#  'P2H4',
#  'HCONH2',
#  'CH3SH',
#  'BH2Cl',
#  'HCN',
#  'C2H4',
#  'SO2',
#  'HNC',
#  'F2',
#  'HOF',
#  'OF2',
#  'ClF',
#  'HCOOH',
#  'CH3Cl',
#  'HCHO',
#  'SiH3Cl',
#  'HOCl',
#  'HOOH',
#  'HCCF',
#  'BF',
#  'BHF2',
#  'HNS',
#  'HBO',
#  'LiCN',
#  'CO',
#  'CS',
#  'CH2NH',
#  'CH3F',
#  'ClCN',
#  'HCHS',
#  'HCCCl',
#  'HNO',
#  'HCP']

# %%
display_convergence_plots('CO','hf','dipole',False)
# Out:
# CO converged:  0.0              True
# 0.0201593125    False
# 0.040318625     False
# 0.08063725      False
# 0.1612745       False
# dtype: bool

# %%
if False:
    for mol in converged:
        create_polar_diff_plot(mol,d_basis_list[0:3])
# Out:
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/Li2/dipole/freq_Li2-d-aug-cc-pVDZ.out not found!
# did not find output file
# Try and run molecule  Li2
# cp: cannot create regular file '/home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole/freq_Li2-d-aug-cc-pVDZ.tar.gz': File exists
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:21:09 PM EDT 2022\n\n\n   Calculation: freq_Li2-d-aug-cc-pVDZ  (input files: freq.dal and Li2-d-aug-cc-pVDZ.mol)\n   PID        : 139356\n\n   ******************************************* \n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVDZ_139356\n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVDZ.mol\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   Thu Jun 30 09:21:09 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVDZ  (input files: freq.dal and Li2-d-aug-cc-pVDZ.mol)\n   PID        : 139354\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVDZ_139354\n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVDZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:21:09 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVDZ  (input files: freq.dal and Li2-d-aug-cc-pVDZ.mol)\n   PID        : 139355\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVDZ_139355\n\n   Thu Jun 30 09:21:09 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVDZ  (input files: freq.dal and Li2-d-aug-cc-pVDZ.mol)\n   PID        : 139353\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVDZ_139353\n\n\n DALTON: default work memory size used.            64000000\n\n DALTON: default work memory size used.            64000000\n\n\n\n DALTON: default work memory size used.            64000000\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_Li2-d-aug-cc-pVDZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\nfreq_Li2-d-aug-cc-pVDZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n---------------------- ...
# did not find output file
# Try and run molecule  Li2
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/Li2/dipole/freq_Li2-d-aug-cc-pVTZ.out not found!
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVTZ.mol\n\n   Thu Jun 30 09:21:11 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVTZ  (input files: freq.dal and Li2-d-aug-cc-pVTZ.mol)\n   PID        : 139555\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVTZ_139555\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVTZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVTZ.mol\n\n   Thu Jun 30 09:21:11 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVTZ  (input files: freq.dal and Li2-d-aug-cc-pVTZ.mol)\n   PID        : 139554\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVTZ_139554\n\n   Thu Jun 30 09:21:11 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVTZ  (input files: freq.dal and Li2-d-aug-cc-pVTZ.mol)\n   PID        : 139553\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVTZ_139553\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVTZ.mol\n\n   Thu Jun 30 09:21:11 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVTZ  (input files: freq.dal and Li2-d-aug-cc-pVTZ.mol)\n   PID        : 139556\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVTZ_139556\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_Li2-d-aug-cc-pVTZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\nfreq_Li2-d-aug-cc-pVTZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n---------------------- ...
# did not find output file
# Try and run molecule  Li2
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/Li2/dipole/freq_Li2-d-aug-cc-pVQZ.out not found!
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVQZ.mol\n\n   Thu Jun 30 09:21:15 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVQZ  (input files: freq.dal and Li2-d-aug-cc-pVQZ.mol)\n   PID        : 139757\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVQZ_139757\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVQZ.mol\n\n   Thu Jun 30 09:21:15 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVQZ  (input files: freq.dal and Li2-d-aug-cc-pVQZ.mol)\n   PID        : 139758\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVQZ_139758\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVQZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Li2-d-aug-cc-pVQZ.mol\n\n   Thu Jun 30 09:21:15 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVQZ  (input files: freq.dal and Li2-d-aug-cc-pVQZ.mol)\n   PID        : 139755\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVQZ_139755\n\n   Thu Jun 30 09:21:15 PM EDT 2022\n\n   Calculation: freq_Li2-d-aug-cc-pVQZ  (input files: freq.dal and Li2-d-aug-cc-pVQZ.mol)\n   PID        : 139756\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_Li2-d-aug-cc-pVQZ_139756\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_Li2-d-aug-cc-pVQZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/Li2/dipole\n----------------------------------------------------------\n1 informational messages have been issued by DALTON,\noutput from 'grep -n INFO' ...
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/NaCl/dipole/freq_NaCl-d-aug-cc-pVDZ.out not found!
# did not find output file
# Try and run molecule  NaCl
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVDZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:21:44 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVDZ  (input files: freq.dal and NaCl-d-aug-cc-pVDZ.mol)\n   PID        : 140034\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVDZ_140034\n\n   Thu Jun 30 09:21:44 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVDZ  (input files: freq.dal and NaCl-d-aug-cc-pVDZ.mol)\n   PID        : 140035\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVDZ_140035\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:21:44 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVDZ  (input files: freq.dal and NaCl-d-aug-cc-pVDZ.mol)\n   PID        : 140033\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVDZ_140033\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:21:44 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVDZ  (input files: freq.dal and NaCl-d-aug-cc-pVDZ.mol)\n   PID        : 140036\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVDZ_140036\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_NaCl-d-aug-cc-pVDZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\nBackup: renaming /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole/freq_NaCl-d-aug-cc-pVDZ.tar. ...
# did not find output file
# Try and run molecule  NaCl
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/NaCl/dipole/freq_NaCl-d-aug-cc-pVTZ.out not found!
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVTZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVTZ.mol\n\n   Thu Jun 30 09:21:47 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVTZ  (input files: freq.dal and NaCl-d-aug-cc-pVTZ.mol)\n   PID        : 140529\n\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVTZ_140529\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVTZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVTZ.mol\n\n   Thu Jun 30 09:21:47 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVTZ  (input files: freq.dal and NaCl-d-aug-cc-pVTZ.mol)\n   PID        : 140530\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVTZ_140530\n\n   Thu Jun 30 09:21:47 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVTZ  (input files: freq.dal and NaCl-d-aug-cc-pVTZ.mol)\n   PID        : 140531\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVTZ_140531\n\n   Thu Jun 30 09:21:47 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVTZ  (input files: freq.dal and NaCl-d-aug-cc-pVTZ.mol)\n   PID        : 140533\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVTZ_140533\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_NaCl-d-aug-cc-pVTZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n----------------------------------------------------------\n1 informational messages have been issued by DALTON,\n ...
# did not find output file
# Try and run molecule  NaCl
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/NaCl/dipole/freq_NaCl-d-aug-cc-pVQZ.out not found!
# cp: cannot create regular file '/home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole/freq_NaCl-d-aug-cc-pVQZ.tar.gz': File exists
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVQZ.mol\n\n   Thu Jun 30 09:21:57 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVQZ  (input files: freq.dal and NaCl-d-aug-cc-pVQZ.mol)\n   PID        : 141640\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVQZ_141640\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVQZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVQZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal NaCl-d-aug-cc-pVQZ.mol\n\n   Thu Jun 30 09:21:57 PM EDT 2022\n\n   Thu Jun 30 09:21:57 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVQZ  (input files: freq.dal and NaCl-d-aug-cc-pVQZ.mol)\n   PID        : 141641\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVQZ_141641\n\n   Calculation: freq_NaCl-d-aug-cc-pVQZ  (input files: freq.dal and NaCl-d-aug-cc-pVQZ.mol)\n   PID        : 141642\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVQZ_141642\n\n   Thu Jun 30 09:21:57 PM EDT 2022\n\n   Calculation: freq_NaCl-d-aug-cc-pVQZ  (input files: freq.dal and NaCl-d-aug-cc-pVQZ.mol)\n   PID        : 141639\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_NaCl-d-aug-cc-pVQZ_141639\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_NaCl-d-aug-cc-pVQZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/dipole\nfreq_NaCl-d-aug-cc-pVQZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/NaCl/di ...
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/BH3/dipole/freq_BH3-d-aug-cc-pVDZ.out not found!
# did not find output file
# Try and run molecule  BH3
# mv: cannot stat '/home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole/freq_BH3-d-aug-cc-pVDZ.out': No such file or directory
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/BH3/dipole/freq_BH3-d-aug-cc-pVTZ.out not found!
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:23:17 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVDZ  (input files: freq.dal and BH3-d-aug-cc-pVDZ.mol)\n   PID        : 141931\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVDZ_141931\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:23:17 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVDZ  (input files: freq.dal and BH3-d-aug-cc-pVDZ.mol)\n   PID        : 141929\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVDZ_141929\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVDZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:23:17 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVDZ  (input files: freq.dal and BH3-d-aug-cc-pVDZ.mol)\n   PID        : 141930\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVDZ_141930\n\n   Thu Jun 30 09:23:17 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVDZ  (input files: freq.dal and BH3-d-aug-cc-pVDZ.mol)\n   PID        : 141932\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVDZ_141932\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_BH3-d-aug-cc-pVDZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\nfreq_BH3-d-aug-cc-pVDZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\nfreq_BH3-d-aug-cc-pVDZ ...
# did not find output file
# Try and run molecule  BH3
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVTZ.mol\n\n   Thu Jun 30 09:23:19 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVTZ  (input files: freq.dal and BH3-d-aug-cc-pVTZ.mol)\n   PID        : 142114\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVTZ_142114\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVTZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVTZ.mol\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVTZ.mol\n\n   Thu Jun 30 09:23:19 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVTZ  (input files: freq.dal and BH3-d-aug-cc-pVTZ.mol)\n   PID        : 142115\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVTZ_142115\n\n   Thu Jun 30 09:23:19 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVTZ  (input files: freq.dal and BH3-d-aug-cc-pVTZ.mol)\n   PID        : 142113\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVTZ_142113\n\n   Thu Jun 30 09:23:19 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVTZ  (input files: freq.dal and BH3-d-aug-cc-pVTZ.mol)\n   PID        : 142116\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVTZ_142116\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_BH3-d-aug-cc-pVTZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n----------------------------------------------------------\n1 informational messages have been issued by DALTON,\noutput from 'grep -n INFO' ...
# did not find output file
# Try and run molecule  BH3
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/BH3/dipole/freq_BH3-d-aug-cc-pVQZ.out not found!
# b'\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVQZ.mol\n\n   Thu Jun 30 09:23:41 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVQZ  (input files: freq.dal and BH3-d-aug-cc-pVQZ.mol)\n   PID        : 142468\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVQZ_142468\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVQZ.mol\n\n   Thu Jun 30 09:23:41 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVQZ  (input files: freq.dal and BH3-d-aug-cc-pVQZ.mol)\n   PID        : 142467\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVQZ_142467\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVQZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal BH3-d-aug-cc-pVQZ.mol\n\n   Thu Jun 30 09:23:41 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVQZ  (input files: freq.dal and BH3-d-aug-cc-pVQZ.mol)\n   PID        : 142469\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVQZ_142469\n\n   Thu Jun 30 09:23:41 PM EDT 2022\n\n   Calculation: freq_BH3-d-aug-cc-pVQZ  (input files: freq.dal and BH3-d-aug-cc-pVQZ.mol)\n   PID        : 142466\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_BH3-d-aug-cc-pVQZ_142466\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_BH3-d-aug-cc-pVQZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/BH3/dipole\n----------------------------------------------------------\n1 informational messages have been issued by DALTON,\noutput from \'grep -n INFO ...
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/CH3OH/dipole/freq_CH3OH-d-aug-cc-pVDZ.out not found!
# did not find output file
# Try and run molecule  CH3OH
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal CH3OH-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:30:29 PM EDT 2022\n\n   Calculation: freq_CH3OH-d-aug-cc-pVDZ  (input files: freq.dal and CH3OH-d-aug-cc-pVDZ.mol)\n   PID        : 143139\n\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_CH3OH-d-aug-cc-pVDZ_143139\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal CH3OH-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:30:29 PM EDT 2022\n\n   Calculation: freq_CH3OH-d-aug-cc-pVDZ  (input files: freq.dal and CH3OH-d-aug-cc-pVDZ.mol)\n   PID        : 143140\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_CH3OH-d-aug-cc-pVDZ_143140\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal CH3OH-d-aug-cc-pVDZ.mol\n\n\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal CH3OH-d-aug-cc-pVDZ.mol\n\n   Thu Jun 30 09:30:29 PM EDT 2022\n\n   Calculation: freq_CH3OH-d-aug-cc-pVDZ  (input files: freq.dal and CH3OH-d-aug-cc-pVDZ.mol)\n   PID        : 143137\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_CH3OH-d-aug-cc-pVDZ_143137\n\n   Thu Jun 30 09:30:29 PM EDT 2022\n\n   Calculation: freq_CH3OH-d-aug-cc-pVDZ  (input files: freq.dal and CH3OH-d-aug-cc-pVDZ.mol)\n   PID        : 143138\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_CH3OH-d-aug-cc-pVDZ_143138\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_CH3OH-d-aug-cc-pVDZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n----------------------------------------------------------\n1 informational messages hav ...
# did not find output file
# Try and run molecule  CH3OH
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/CH3OH/dipole/freq_CH3OH-d-aug-cc-pVTZ.out not found!
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal CH3OH-d-aug-cc-pVTZ.mol\n\n\n\n   ******************************************* \n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal CH3OH-d-aug-cc-pVTZ.mol\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal CH3OH-d-aug-cc-pVTZ.mol\n\n   Thu Jun 30 09:30:43 PM EDT 2022\n\n\n   Calculation: freq_CH3OH-d-aug-cc-pVTZ  (input files: freq.dal and CH3OH-d-aug-cc-pVTZ.mol)\n   PID        : 143420\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_CH3OH-d-aug-cc-pVTZ_143420\n\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal CH3OH-d-aug-cc-pVTZ.mol\n\n   Thu Jun 30 09:30:43 PM EDT 2022\n\n   Calculation: freq_CH3OH-d-aug-cc-pVTZ  (input files: freq.dal and CH3OH-d-aug-cc-pVTZ.mol)\n   PID        : 143419\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_CH3OH-d-aug-cc-pVTZ_143419\n\n   Thu Jun 30 09:30:43 PM EDT 2022\n\n   Calculation: freq_CH3OH-d-aug-cc-pVTZ  (input files: freq.dal and CH3OH-d-aug-cc-pVTZ.mol)\n   PID        : 143417\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_CH3OH-d-aug-cc-pVTZ_143417\n\n   Thu Jun 30 09:30:43 PM EDT 2022\n\n   Calculation: freq_CH3OH-d-aug-cc-pVTZ  (input files: freq.dal and CH3OH-d-aug-cc-pVTZ.mol)\n   PID        : 143418\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n   Scratch dir: /media/adrianhurtado/NewScratch/DALTON_scratch_adrianhurtado/freq_CH3OH-d-aug-cc-pVTZ_143418\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole:/home/adrianhurtado/projects/dalton/build/basis\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_CH3OH-d-aug-cc-pVTZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/dalton/hf/CH3OH/dipole\n----------------------------------------------------------\n1 informational messages hav ...
# did not find output file
# Try and run molecule  CH3OH
# File /home/adrianhurtado/testing/madness-test-suite/large_polar_low/../dalton/hf/CH3OH/dipole/freq_CH3OH-d-aug-cc-pVQZ.out not found!
#
#  NOTE:    1 warnings have been issued.
#  Check output, result, and error files for "WARNING".
#
#  NOTE:    1 warnings have been issued.
#  Check output, result, and error files for "WARNING".
#
#  NOTE:    1 warnings have been issued.
#  Check output, result, and error files for "WARNING".
#
#  NOTE:    1 warnings have been issued.
#  Check output, result, and error files for "WARNING".
