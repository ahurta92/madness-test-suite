# %%
import os
os.chdir("/home/adrianhurtado/testing/madness-test-suite/development")
from madnessReader import MadnessReader
from daltonRunner import DaltonRunner
# Out:
# /home/adrianhurtado/testing/madness-test-suite/development

# %%
drunner=DaltonRunner()
mreader=MadnessReader()
excited=mreader.get_excited_result("Ne",'hf')
excited
# Out:
# /home/adrianhurtado/testing/madness-test-suite/development
# {'conv_only_dens': False, 'dconv': 0.0001, 'dconv_set': False, 'dipole': False, 'e_range': False, 'e_range_hi': 1.0, 'e_range_lo': 0.0, 'excited_state': True, 'first_order': False, 'first_run': True, 'guess_max_iter': 5, 'guess_xyz': False, 'k': -1, 'kain': True, 'l': 200.0, 'larger_subspace': 0, 'lo': 0.00091626, 'load_density': False, 'loadbalparts': 2, 'maxbsh': 10.0, 'maxiter': 20, 'maxrotn': 0.1, 'maxsub': 10, 'nuclear': False, 'num_orbitals': 5, 'nwchem': False, 'omega': 0.0, 'order2': False, 'order3': False, 'plot': False, 'plot_all_orbitals': True, 'plot_cell': [], 'plot_initial': False, 'plot_l': -1.0, 'plot_pts': 201, 'plot_range': False, 'print_level': 15, 'protocol': [0.0001, 1e-06], 'random': False, 'restart': False, 'save': True, 'save_density': False, 'second_order': False, 'spinrestricted': True, 'states': 4, 'store_potential': False, 'tda': False, 'third_order': False, 'vnucextra': 2}
# iterations    37.000000
# k              8.000000
# thresh         0.000001
# 0              0.674083
# 1              0.674085
# 2              0.674343
# 3              0.738720
# Name: 37, dtype: float64
# iterations    37.000000
# k              8.000000
# thresh         0.000001
# d0             0.000005
# d1             0.000007
# d2             0.000298
# d3             0.000004
# x0             0.000075
# x1             0.000059
# x2             0.009973
# x3             0.003537
# y0             0.000003
# y1             0.000003
# y2             0.000259
# y3             0.000229
# Name: 37, dtype: float64

# %%
params,o_df,r_df=mreader.get_excited_data("Ne",'hf')
# Out:
# /home/adrianhurtado/testing/madness-test-suite/development

# %%
r_df
# Out:
#     iterations    k    thresh        d0        d1        d2        d3  \
# 0            0  6.0  0.000100  0.000000  0.000000  0.000000  0.000000
# 1            1  6.0  0.000100  0.002892  0.003625  0.004995  0.001886
# 2            2  6.0  0.000100  0.000558  0.001786  0.002597  0.000608
# 3            3  6.0  0.000100  0.002794  0.001403  0.001768  0.000403
# 4            4  6.0  0.000100  0.027110  0.079258  0.001238  0.000314
# 5            5  6.0  0.000100  0.018138  0.000969  0.018900  0.000261
# 6            6  6.0  0.000100  0.007087  0.026048  0.068509  0.001424
# 7            7  6.0  0.000100  0.062696  0.040584  0.057261  0.102662
# 8            8  6.0  0.000100  0.015617  0.058820  0.063696  0.004572
# 9            9  6.0  0.000100  0.006798  0.062014  0.035116  0.000608
# 10          10  6.0  0.000100  0.073552  0.061925  0.083217  0.091913
# 11          11  6.0  0.000100  0.039044  0.059725  0.070748  0.078840
# 12          12  6.0  0.000100  0.189692  0.056053  0.098645  0.096858
# 13          13  6.0  0.000100  0.031484  0.058779  0.054910  0.003064
# 14          14  6.0  0.000100  0.052674  0.056165  0.032576  0.109581
# 15          15  6.0  0.000100  0.042800  0.050966  0.044322  0.107701
# 16          16  6.0  0.000100  0.097535  0.053479  0.036589  0.070636
# 17          17  6.0  0.000100  0.093417  0.057985  0.099345  0.091519
# 18          18  6.0  0.000100  0.018321  0.055462  0.063093  0.011507
# 19          19  8.0  0.000001  0.000000  0.000000  0.000000  0.000000
# 20          20  8.0  0.000001  0.001652  0.002281  0.003300  0.044981
# 26  0.000074  0.000061  0.034593   0.004077  0.000004  0.000005  0.000571
# 27  0.000075  0.000059  0.029513   0.003959  0.000004  0.000004  0.000532
# 28  0.000074  0.000059  0.025440   0.003866  0.000003  0.000003  0.000493
# 29  0.000074  0.000059  0.022149   0.003792  0.000009  0.000004  0.000457
# 30  0.000074  0.000059  0.019469   0.003732  0.000005  0.000003  0.000422
# 31  0.000074  0.000059  0.017271   0.003684  0.000004  0.000004  0.000390
# 32  0.000074  0.000059  0.015455   0.003646  0.000005  0.000007  0.000361
# 33  0.000074  0.000059  0.013947   0.003614  0.000004  0.000005  0.000336
# 34  0.000075  0.000059  0.012686   0.003589  0.000004  0.000004  0.000313
# 35  0.000075  0.000059  0.011627   0.003568  0.000004  0.000004  0.000292
# 36  0.000075  0.000059  0.010732   0.003551  0.000004  0.000005  0.000274
# 37  0.000075  0.000059  0.009973   0.003537  0.000003  0.000003  0.000259
#
#           y3
# 0   0.005556
# 1   0.001833
# 2   0.001287
# 3   0.001020
# 4   0.000841
# 5   0.000793
# 6   0.021142
# 7   0.001737
# 8   0.000814
# 9   0.014933
# 10  0.010855
# 11  0.011711
# 12  0.000852
# 13  0.064383
# 14  0.072814
# 15  0.032151
# 16  0.033212
# 17  0.002526
# 18  0.006403
# 19  0.010444
# 20  0.000475
# 21  0.000408
# 22  0.000365
# 23  0.000334
# 24  0.000311
# 25  0.000293
# 26  0.000279
# 27  0.000268
# 28  0.000260
# 29  0.000253
# 30  0.000247
# 31  0.000243
# 32  0.000239
# 33  0.000237
# 34  0.000234
# 35  0.000232
# 36  0.000231
# 37  0.000229

# %%
r_df.iloc[:,3:6].plot()
# Out:
# <AxesSubplot:>

# %%
r_df.iloc[:,7:].plot()
# Out:
# <AxesSubplot:>

# %%
excited=mreader.get_excited_result("Be",'hf')
# Out:
# /home/adrianhurtado/testing/madness-test-suite/development
# {'conv_only_dens': False, 'dconv': 0.0001, 'dconv_set': False, 'dipole': False, 'e_range': False, 'e_range_hi': 1.0, 'e_range_lo': 0.0, 'excited_state': True, 'first_order': False, 'first_run': True, 'guess_max_iter': 5, 'guess_xyz': False, 'k': -1, 'kain': True, 'l': 200.0, 'larger_subspace': 0, 'lo': 0.0042194, 'load_density': False, 'loadbalparts': 2, 'maxbsh': 10.0, 'maxiter': 20, 'maxrotn': 0.1, 'maxsub': 10, 'nuclear': False, 'num_orbitals': 2, 'nwchem': False, 'omega': 0.0, 'order2': False, 'order3': False, 'plot': False, 'plot_all_orbitals': True, 'plot_cell': [], 'plot_initial': False, 'plot_l': -1.0, 'plot_pts': 201, 'plot_range': False, 'print_level': 15, 'protocol': [0.0001, 1e-06], 'random': False, 'restart': False, 'save': True, 'save_density': False, 'second_order': False, 'spinrestricted': True, 'states': 4, 'store_potential': False, 'tda': False, 'third_order': False, 'vnucextra': 2}
# iterations    37.000000
# k              8.000000
# thresh         0.000001
# 0              0.176299
# 1              0.176300
# 2              0.176394
# 3              0.224929
# Name: 37, dtype: float64
# iterations    37.000000
# k              8.000000
# thresh         0.000001
# d0             0.000004
# d1             0.043215
# d2             0.050380
# d3             0.000006
# x0             0.000087
# x1             0.000123
# x2             0.001017
# x3             0.010474
# y0             0.000014
# y1             0.000066
# y2             0.000459
# y3             0.000220
# Name: 37, dtype: float64

# %%
def compare_excited(mol,xc,basis):
    ground_mad=mreader.get_ground_scf_data(mol,xc)
    params,omega,residuals=mreader.get_excited_data(mol,xc)
    print(params)
    gdalton,rdalton=drunner.get_excited_result(mol,xc,basis)
    
    
compare_excited('Be','hf','aug-cc-pvQZ')
# Out:
# /home/adrianhurtado/testing/madness-test-suite/development
# {'conv_only_dens': False, 'dconv': 0.0001, 'dconv_set': False, 'dipole': False, 'e_range': False, 'e_range_hi': 1.0, 'e_range_lo': 0.0, 'excited_state': True, 'first_order': False, 'first_run': True, 'guess_max_iter': 5, 'guess_xyz': False, 'k': -1, 'kain': True, 'l': 200.0, 'larger_subspace': 0, 'lo': 0.0042194, 'load_density': False, 'loadbalparts': 2, 'maxbsh': 10.0, 'maxiter': 20, 'maxrotn': 0.1, 'maxsub': 10, 'nuclear': False, 'num_orbitals': 2, 'nwchem': False, 'omega': 0.0, 'order2': False, 'order3': False, 'plot': False, 'plot_all_orbitals': True, 'plot_cell': [], 'plot_initial': False, 'plot_l': -1.0, 'plot_pts': 201, 'plot_range': False, 'print_level': 15, 'protocol': [0.0001, 1e-06], 'random': False, 'restart': False, 'save': True, 'save_density': False, 'second_order': False, 'spinrestricted': True, 'states': 4, 'store_potential': False, 'tda': False, 'third_order': False, 'vnucextra': 2}
# iterations    37.000000
# k              8.000000
# thresh         0.000001
# 0              0.176299
# 1              0.176300
# 2              0.176394
# 3              0.224929
# Name: 37, dtype: float64
# iterations    37.000000
# k              8.000000
# thresh         0.000001
# d0             0.000004
# d1             0.043215
# d2             0.050380
# d3             0.000006
# x0             0.000087
# x1             0.000123
# x2             0.001017
# x3             0.010474
# y0             0.000014
# y1             0.000066
# y2             0.000459
# y3             0.000220
# Name: 37, dtype: float64
# {'t-aug-cc-pVQZ': {'ground': {'calculationType': 'energyCalculation', 'calculationTime': {'cpuTime': 0.568, 'wallTime': 0.568, 'units': 'second'}, 'calculationResults': {'totalEnergy': {'value': -14.572969666523, 'units': 'Hartree'}, 'nuclearRepulsionEnergy': {'value': 0.0, 'units': 'Hartree'}, 'electronEnergy': {'value': -14.572969666523, 'units': 'Hartree'}}, 'calculationSetup': {'numberOfElectrons': 4, 'molecularSpinMultiplicity': 1, 'waveFunctionType': 'HF', 'waveFunctionTheory': 'Hartree-Fock', 'charge': 0}}, 'response': {'Sym': [2, 3, 5, 1, 2, 3, 5, 1, 1, 7, 6, 4, 1, 6, 4, 7, 5, 3, 2, 3, 5, 2, 8, 8, 6, 4, 7, 4, 6, 7, 8, 8], 'Mode': [1, 1, 1, 1, 2, 2, 2, 2, 3, 1, 1, 1, 4, 2, 2, 2, 3, 3, 3, 4, 4, 4, 1, 2, 3, 3, 3, 4, 4, 4, 3, 4], 'freq': [0.176937, 0.176937, 0.176937, 0.224879, 0.248838, 0.248838, 0.248838, 0.254474, 0.254474, 0.254474, 0.254474, 0.254474, 0.26708, 0.279948, 0.279948, 0.279948, 0.282209, 0.282209, 0.282209, 0.28363, 0.28363, 0.28363, 0.28363, 0.352723, 0.354794, 0.354794, 0.354794, 0.377071, 0.377071, 0.377071, 0.580702, 1.237473], 'calculationTime': {'cpuTime': 0.28, 'wallTime': 0.28, 'units': 'second'}}}}

# %%
molecules=['Be','CH4','H2','H2O','He','Ne']
