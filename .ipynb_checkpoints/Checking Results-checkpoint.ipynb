# %%
from daltonRunner import DaltonRunner
from madnessReader import MadnessReader
# Out:
# /home/adrianhurtado/testing/madness-test-suite/madness-test-suite

# %%
drunner=DaltonRunner()
mreader=MadnessReader()

# %%
g,r=drunner.getDaltonFrequencyResults('CH3NH2','hf','dipole','aug-cc-pVQZ')
# Out:
# /freq_CH3NH2-aug-cc-pVQZ.out
# {
#   "simulation": {
#     "calculations": [
#       {
#         "calculationType": "energyCalculation",
#         "calculationTime": {
#           "cpuTime": 203.761,
#           "wallTime": 204.375,
#           "units": "second"
#         },
#         "calculationResults": {
#           "totalEnergy": {
#             "value": -95.26146532799,
#             "units": "Hartree"
#           },
#           "nuclearRepulsionEnergy": {
#             "value": 42.095892670917,
#             "units": "Hartree"
#           },
#           "electronEnergy": {
#             "value": -137.357357998906,
#             "units": "Hartree"
#           }
#         },
#         "calculationSetup": {
#           "numberOfElectrons": 18,
#           "molecularSpinMultiplicity": 1,
#           "waveFunctionType": "HF",
#           "waveFunctionTheory": "Hartree-Fock",
#           "charge": 0
#         }
#       },
#       {
#         "calculationType": "LinearResponse",
#         "calculationTime": {
#           "cpuTime": 12.0,
#           "wallTime": 12.0,
#           "units": "second"
#         },
#         "calculationResults": {
#           "xx": [
#             22.77366294503,
#             22.79479174662,
#             22.85860121989,
#             23.12044673959,
#             24.29414339453
#           ],
#           "xy": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "xz": [
#             -0.02700539277676,
#             -0.02514773755415,
#             -0.01948826200044,
#             0.004513281272345,
#             0.1274246213554
#           ],
#           "yx": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "yy": [
#             22.90317876879,
#             22.92009142682,
#             22.97103412391,
#             23.17793788562,
#             24.060006159
#           ],
#           "yz": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zx": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zy": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zz": [
#             26.35803565929,
#             26.38036901781,
#             26.44769567682,
#             26.7220314874,
#             27.90928990368
#           ]
#         },
#         "calculationSetup": {
#           "frequencies": [
#             0.0,
#             0.0159075,
#             0.031815,
#             0.06363,
#             0.12726
#           ],
#           "numFrequencies": 5
#         }
#       }
#     ],
#     "simulationTime": {
#       "cpuTime": 16.0,
#       "wallTime": 16.0,
#       "units": "second"
#     }
#   }
# }

# %%
r
# Out:
#    frequencies         xx  xy        xz  yx         yy  yz  zx  zy         zz
# 0     0.000000  22.773663   0 -0.027005   0  22.903179   0   0   0  26.358036
# 1     0.015908  22.794792   0 -0.025148   0  22.920091   0   0   0  26.380369
# 2     0.031815  22.858601   0 -0.019488   0  22.971034   0   0   0  26.447696
# 3     0.063630  23.120447   0  0.004513   0  23.177938   0   0   0  26.722031
# 4     0.127260  24.294143   0  0.127425   0  24.060006   0   0   0  27.909290

# %%
p_mad=mreader.get_polar_result('Ne','hf','dipole')
# Out:
# dict_keys(['converged', 'parameters', 'protocol_data'])
# dict_keys(['converged', 'protocol_data', 'response_parameters'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_122459/3102015817.py in <module>
# ----> 1 p_mad=mreader.get_polar_result('Ne','hf','dipole')
#
# ~/testing/madness-test-suite/madness-test-suite/madnessReader.py in get_polar_result(self, mol, xc, operator)
#     195         for f in freq:
#     196             rbasej = self.__open_frequency_rbj(mol, xc, operator, f)
# --> 197             fdata[str(f)] = self.__get_polar_data(rbasej)
#     198
#     199         rdf = pd.DataFrame(fdata).T
#
# ~/testing/madness-test-suite/madness-test-suite/madnessReader.py in __get_polar_data(self, rbase_j)
#     181     def __get_polar_data(self, rbase_j):
#     182         print(rbase_j.keys())
# --> 183         num_states = rbase_j['parameters']['states']
#     184         fp, fres = self.__read_response_protocol_data(
#     185             rbase_j['protocol_data'], num_states)
#
# KeyError: 'parameters'

# %%
p_mad

# %%
def comparePolar(mol,xc,operator,basis):
    p_mad=mreader.get_polar_result(mol,xc,operator)
    scf_calc=mreader.get_ground_scf_data(mol,xc)
    p_mad=p_mad.iloc[:,0:11]
    g,r=drunner.getDaltonFrequencyResults(mol,xc,operator,basis)
    
    print(p_mad)
    print(r)
    
    return g,r, scf_calc,p_mad
    
comparePolar('Ne','hf','dipole','d-aug-cc-pVQZ')
# Out:
# dict_keys(['converged', 'parameters', 'protocol_data'])
# dict_keys(['converged', 'protocol_data', 'response_parameters'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_122459/841399904.py in <module>
#      10     return g,r, scf_calc,p_mad
#      11
# ---> 12 comparePolar('Ne','hf','dipole','d-aug-cc-pVQZ')
#
# /tmp/ipykernel_122459/841399904.py in comparePolar(mol, xc, operator, basis)
#       1 def comparePolar(mol,xc,operator,basis):
# ----> 2     p_mad=mreader.get_polar_result(mol,xc,operator)
#       3     scf_calc=mreader.get_ground_scf_data(mol,xc)
#       4     p_mad=p_mad.iloc[:,0:11]
#       5     g,r=drunner.getDaltonFrequencyResults(mol,xc,operator,basis)
#
# ~/testing/madness-test-suite/madness-test-suite/madnessReader.py in get_polar_result(self, mol, xc, operator)
#     195         for f in freq:
#     196             rbasej = self.__open_frequency_rbj(mol, xc, operator, f)
# --> 197             fdata[str(f)] = self.__get_polar_data(rbasej)
#     198
#     199         rdf = pd.DataFrame(fdata).T
#
# ~/testing/madness-test-suite/madness-test-suite/madnessReader.py in __get_polar_data(self, rbase_j)
#     181     def __get_polar_data(self, rbase_j):
#     182         print(rbase_j.keys())
# --> 183         num_states = rbase_j['parameters']['states']
#     184         fp, fres = self.__read_response_protocol_data(
#     185             rbase_j['protocol_data'], num_states)
#
# KeyError: 'parameters'

# %%
drunner.get_excited_result('Ne','hf','d-aug-cc-pVQZ')
# Out:
# {'d-aug-cc-pVQZ': {'ground': {'calculationType': 'energyCalculation', 'calculationTime': {'cpuTime': 0.561, 'wallTime': 0.572, 'units': 'second'}, 'calculationResults': {'totalEnergy': {'value': -128.543767339621, 'units': 'Hartree'}, 'nuclearRepulsionEnergy': {'value': 0.0, 'units': 'Hartree'}, 'electronEnergy': {'value': -128.543767339621, 'units': 'Hartree'}}, 'calculationSetup': {'numberOfElectrons': 10, 'molecularSpinMultiplicity': 1, 'waveFunctionType': 'HF', 'waveFunctionTheory': 'Hartree-Fock', 'charge': 0}}, 'response': {'Sym': [3, 5, 2, 4, 7, 1, 1, 6, 7, 4, 6, 1, 7, 1, 6, 4, 6, 7, 4, 5, 3, 2, 5, 3, 3, 2, 2, 8, 5, 8, 8, 8], 'Mode': [1, 1, 1, 1, 1, 1, 2, 1, 2, 2, 2, 3, 3, 4, 3, 3, 4, 4, 4, 2, 2, 2, 4, 4, 3, 4, 3, 1, 3, 3, 2, 4], 'freq': [0.674466, 0.674466, 0.674466, 0.739256, 0.739256, 0.739256, 0.739256, 0.739256, 0.740468, 0.740468, 0.740468, 0.756506, 0.866983, 0.866983, 0.866983, 0.866983, 0.867484, 0.867484, 0.867484, 0.88785, 0.88785, 0.88785, 0.915443, 0.915443, 0.915443, 0.915443, 0.915443, 0.915443, 0.915443, 0.9208, 0.9208, 1.477912], 'calculationTime': {'cpuTime': 0.54, 'wallTime': 0.54, 'units': 'second'}}}}
# (basis                     d-aug-cc-pVQZ
#  totalEnergy                 -128.543767
#  nuclearRepulsionEnergy              0.0
#  electronEnergy              -128.543767
#  gcpuTime                          0.561
#  gwallTime                         0.572
#  rcpuTime                           0.54
#  rwallTime                          0.54
#  numberOfElectrons                    10
#  dtype: object,
#      Sym  Mode      freq
#  0     3     1  0.674466
#  1     5     1  0.674466
#  2     2     1  0.674466
#  3     4     1  0.739256
#  4     7     1  0.739256
#  5     1     1  0.739256
#  6     1     2  0.739256
#  7     6     1  0.739256
#  8     7     2  0.740468
#  9     4     2  0.740468
#  10    6     2  0.740468
#  11    1     3  0.756506
#  12    7     3  0.866983
#  13    1     4  0.866983
#  14    6     3  0.866983
#  15    4     3  0.866983
#  16    6     4  0.867484
#  17    7     4  0.867484
#  18    4     4  0.867484
#  19    5     2  0.887850
#  20    3     2  0.887850
#  21    2     2  0.887850
#  22    5     4  0.915443
#  23    3     4  0.915443
#  24    3     3  0.915443
#  25    2     4  0.915443
#  26    2     3  0.915443
#  27    8     1  0.915443
#  28    5     3  0.915443
#  29    8     3  0.920800
#  30    8     2  0.920800
#  31    8     4  1.477912)

# %%
g,r,p=comparePolar('Ne','hf','dipole','d-aug-cc-pV6Z')
# Out:
# dict_keys(['converged', 'parameters', 'protocol_data'])
# dict_keys(['converged', 'protocol_data', 'response_parameters'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_122459/1903526507.py in <module>
# ----> 1 g,r,p=comparePolar('Ne','hf','dipole','d-aug-cc-pV6Z')
#
# /tmp/ipykernel_122459/841399904.py in comparePolar(mol, xc, operator, basis)
#       1 def comparePolar(mol,xc,operator,basis):
# ----> 2     p_mad=mreader.get_polar_result(mol,xc,operator)
#       3     scf_calc=mreader.get_ground_scf_data(mol,xc)
#       4     p_mad=p_mad.iloc[:,0:11]
#       5     g,r=drunner.getDaltonFrequencyResults(mol,xc,operator,basis)
#
# ~/testing/madness-test-suite/madness-test-suite/madnessReader.py in get_polar_result(self, mol, xc, operator)
#     195         for f in freq:
#     196             rbasej = self.__open_frequency_rbj(mol, xc, operator, f)
# --> 197             fdata[str(f)] = self.__get_polar_data(rbasej)
#     198
#     199         rdf = pd.DataFrame(fdata).T
#
# ~/testing/madness-test-suite/madness-test-suite/madnessReader.py in __get_polar_data(self, rbase_j)
#     181     def __get_polar_data(self, rbase_j):
#     182         print(rbase_j.keys())
# --> 183         num_states = rbase_j['parameters']['states']
#     184         fp, fres = self.__read_response_protocol_data(
#     185             rbase_j['protocol_data'], num_states)
#
# KeyError: 'parameters'

# %%
print(g)
print(r)

# %%
g,r=drunner.getDaltonFrequencyResults('Ne','hf','dipole','d-aug-cc-pV6Z')
# Out:
# /freq_Ne-d-aug-cc-pV6Z.out
# {
#   "simulation": {
#     "calculations": [
#       {
#         "calculationType": "energyCalculation",
#         "calculationTime": {
#           "cpuTime": 8.364,
#           "wallTime": 8.375,
#           "units": "second"
#         },
#         "calculationResults": {
#           "totalEnergy": {
#             "value": -128.547062677085,
#             "units": "Hartree"
#           },
#           "nuclearRepulsionEnergy": {
#             "value": 0.0,
#             "units": "Hartree"
#           },
#           "electronEnergy": {
#             "value": -128.547062677085,
#             "units": "Hartree"
#           }
#         },
#         "calculationSetup": {
#           "numberOfElectrons": 10,
#           "molecularSpinMultiplicity": 1,
#           "waveFunctionType": "HF",
#           "waveFunctionTheory": "Hartree-Fock",
#           "charge": 0
#         }
#       },
#       {
#         "calculationType": "LinearResponse",
#         "calculationTime": {
#           "cpuTime": 2.6,
#           "wallTime": 2.6,
#           "units": "second"
#         },
#         "calculationResults": {
#           "xx": [
#             2.376422894051,
#             2.380905038959,
#             2.394517353204,
#             2.451615157792,
#             2.736236872796
#           ],
#           "xy": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "xz": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "yx": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "yy": [
#             2.376422894052,
#             2.380905038959,
#             2.394517353204,
#             2.451615157792,
#             2.736236872797
#           ],
#           "yz": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zx": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zy": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zz": [
#             2.376422894051,
#             2.380905038958,
#             2.394517353203,
#             2.451615157792,
#             2.736236872795
#           ]
#         },
#         "calculationSetup": {
#           "frequencies": [
#             0.0,
#             0.04612212,
#             0.09224425,
#             0.1844885,
#             0.368977
#           ],
#           "numFrequencies": 5
#         }
#       }
#     ],
#     "simulationTime": {
#       "cpuTime": 11.09,
#       "wallTime": 11.09,
#       "units": "second"
#     }
#   }
# }

# %%
g,r=drunner.getDaltonFrequencyResults('Ne','hf','dipole','d-aug-cc-pCVQZ')
# Out:
# /freq_Ne-d-aug-cc-pCVQZ.out
# {
#   "simulation": {
#     "calculations": [
#       {
#         "calculationType": "energyCalculation",
#         "calculationTime": {
#           "cpuTime": 0.623,
#           "wallTime": 0.626,
#           "units": "second"
#         },
#         "calculationResults": {
#           "totalEnergy": {
#             "value": -128.543864576961,
#             "units": "Hartree"
#           },
#           "nuclearRepulsionEnergy": {
#             "value": 0.0,
#             "units": "Hartree"
#           },
#           "electronEnergy": {
#             "value": -128.543864576961,
#             "units": "Hartree"
#           }
#         },
#         "calculationSetup": {
#           "numberOfElectrons": 10,
#           "molecularSpinMultiplicity": 1,
#           "waveFunctionType": "HF",
#           "waveFunctionTheory": "Hartree-Fock",
#           "charge": 0
#         }
#       },
#       {
#         "calculationType": "LinearResponse",
#         "calculationTime": {
#           "cpuTime": 0.48,
#           "wallTime": 0.48,
#           "units": "second"
#         },
#         "calculationResults": {
#           "xx": [
#             2.379728178192,
#             2.384200791037,
#             2.397783445721,
#             2.45474449279,
#             2.73831973939
#           ],
#           "xy": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "xz": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "yx": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "yy": [
#             2.379728178191,
#             2.384200791036,
#             2.39778344572,
#             2.454744492788,
#             2.738319739387
#           ],
#           "yz": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zx": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zy": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zz": [
#             2.379728178191,
#             2.384200791036,
#             2.39778344572,
#             2.454744492789,
#             2.738319739388
#           ]
#         },
#         "calculationSetup": {
#           "frequencies": [
#             0.0,
#             0.04612212,
#             0.09224425,
#             0.1844885,
#             0.368977
#           ],
#           "numFrequencies": 5
#         }
#       }
#     ],
#     "simulationTime": {
#       "cpuTime": 1.16,
#       "wallTime": 1.16,
#       "units": "second"
#     }
#   }
# }

# %%
g,r=drunner.getDaltonFrequencyResults('Ne','hf','dipole','d-aug-cc-pV5Z')
# Out:
# /freq_Ne-d-aug-cc-pV5Z.out
# {
#   "simulation": {
#     "calculations": [
#       {
#         "calculationType": "energyCalculation",
#         "calculationTime": {
#           "cpuTime": 2.137,
#           "wallTime": 2.145,
#           "units": "second"
#         },
#         "calculationResults": {
#           "totalEnergy": {
#             "value": -128.546788391395,
#             "units": "Hartree"
#           },
#           "nuclearRepulsionEnergy": {
#             "value": 0.0,
#             "units": "Hartree"
#           },
#           "electronEnergy": {
#             "value": -128.546788391395,
#             "units": "Hartree"
#           }
#         },
#         "calculationSetup": {
#           "numberOfElectrons": 10,
#           "molecularSpinMultiplicity": 1,
#           "waveFunctionType": "HF",
#           "waveFunctionTheory": "Hartree-Fock",
#           "charge": 0
#         }
#       }
#     ],
#     "simulationTime": {
#       "cpuTime": 2.24,
#       "wallTime": 2.24,
#       "units": "second"
#     }
#   }
# }
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_122459/1944335473.py in <module>
# ----> 1 g,r=drunner.getDaltonFrequencyResults('Ne','hf','dipole','d-aug-cc-pV5Z')
#
# ~/testing/madness-test-suite/madness-test-suite/daltonRunner.py in getDaltonFrequencyResults(self, mol, xc, operator, basis)
#     272     def getDaltonFrequencyResults(self,mol,xc,operator,basis):
#     273
# --> 274         dipole_j=self.get_polar_json(mol,xc,operator,basis)[basis]
#     275         time=dipole_j['ground']['calculationTime']
#     276         results=dipole_j['ground']['calculationResults']
#
# ~/testing/madness-test-suite/madness-test-suite/daltonRunner.py in get_polar_json(self, mol, xc, operator, basis)
#     191             with open(outfile,'r')as daltonOutput:
#     192                 dj=daltonToJson()
# --> 193                 data=self.__create_frequency_json(dj.convert(daltonOutput),basis)
#     194         except FileNotFoundError as e:
#     195             print(f"File {outfile} not found!", file=sys.stderr)
#
# ~/testing/madness-test-suite/madness-test-suite/daltonRunner.py in __create_frequency_json(self, outfile, basis)
#     133         r_dict['frequencies']=[]
#     134         e_data=json.loads(outfile)['simulation']['calculations'][0]
# --> 135         r_data=json.loads(outfile)['simulation']['calculations'][1]
#     136
#     137         p_data=r_data['calculationResults']
#
# IndexError: list index out of range

# %%
g,r=drunner.getDaltonFrequencyResults('Ne','hf','dipole','d-aug-cc-pV5Z')
# Out:
# /freq_Ne-d-aug-cc-pV5Z.out
# {
#   "simulation": {
#     "calculations": [
#       {
#         "calculationType": "energyCalculation",
#         "calculationTime": {
#           "cpuTime": 2.137,
#           "wallTime": 2.145,
#           "units": "second"
#         },
#         "calculationResults": {
#           "totalEnergy": {
#             "value": -128.546788391395,
#             "units": "Hartree"
#           },
#           "nuclearRepulsionEnergy": {
#             "value": 0.0,
#             "units": "Hartree"
#           },
#           "electronEnergy": {
#             "value": -128.546788391395,
#             "units": "Hartree"
#           }
#         },
#         "calculationSetup": {
#           "numberOfElectrons": 10,
#           "molecularSpinMultiplicity": 1,
#           "waveFunctionType": "HF",
#           "waveFunctionTheory": "Hartree-Fock",
#           "charge": 0
#         }
#       }
#     ],
#     "simulationTime": {
#       "cpuTime": 2.24,
#       "wallTime": 2.24,
#       "units": "second"
#     }
#   }
# }
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_122459/1944335473.py in <module>
# ----> 1 g,r=drunner.getDaltonFrequencyResults('Ne','hf','dipole','d-aug-cc-pV5Z')
#
# ~/testing/madness-test-suite/madness-test-suite/daltonRunner.py in getDaltonFrequencyResults(self, mol, xc, operator, basis)
#     272     def getDaltonFrequencyResults(self,mol,xc,operator,basis):
#     273
# --> 274         dipole_j=self.get_polar_json(mol,xc,operator,basis)[basis]
#     275         time=dipole_j['ground']['calculationTime']
#     276         results=dipole_j['ground']['calculationResults']
#
# ~/testing/madness-test-suite/madness-test-suite/daltonRunner.py in get_polar_json(self, mol, xc, operator, basis)
#     191             with open(outfile,'r')as daltonOutput:
#     192                 dj=daltonToJson()
# --> 193                 data=self.__create_frequency_json(dj.convert(daltonOutput),basis)
#     194         except FileNotFoundError as e:
#     195             print(f"File {outfile} not found!", file=sys.stderr)
#
# ~/testing/madness-test-suite/madness-test-suite/daltonRunner.py in __create_frequency_json(self, outfile, basis)
#     133         r_dict['frequencies']=[]
#     134         e_data=json.loads(outfile)['simulation']['calculations'][0]
# --> 135         r_data=json.loads(outfile)['simulation']['calculations'][1]
#     136
#     137         p_data=r_data['calculationResults']
#
# IndexError: list index out of range

# %%
basis=['d-aug-cc-pVDZ']
basis.append('d-aug-cc-pVTZ')
basis.append('d-aug-cc-pVQZ')
basis.append('d-aug-cc-pV5Z')
basis.append('d-aug-cc-pV6Z')

gE=[]
alpha=[]
for b in basis:
    g,r=drunner.getDaltonFrequencyResults('Ne','hf','dipole',b)
    g['simulation']['calculations']['calculationResults']["totalEnergy"]["value"]
    r['calculationResults']['xx'][0]
# Out:
# /freq_Ne-d-aug-cc-pVDZ.out
# did not find output file
# Try and run molecule  Ne
# File /home/adrianhurtado/testing/madness-test-suite/madness-test-suite/dalton/hf/Ne/dipole/freq_Ne-d-aug-cc-pVDZ.out not found!
# b"\n   ******************************************* \n   **** OUTPUT FROM DALTON SHELL SCRIPT\n   ******************************************* \n\n   DALTON release Dalton2020.1 (2022)\n\n   Invocation: /home/adrianhurtado/projects/dalton/build/dalton freq.dal Ne-d-aug-cc-pVDZ.mol\n\n   Fri Apr 22 05:51:01 PM EDT 2022\n\n   Calculation: freq_Ne-d-aug-cc-pVDZ  (input files: freq.dal and Ne-d-aug-cc-pVDZ.mol)\n   PID        : 214524\n   Input dir  : /home/adrianhurtado/testing/madness-test-suite/madness-test-suite/dalton/hf/Ne/dipole\n   Scratch dir: /media/adrianhurtado/00947d28-056d-4e5c-a97f-98acff79841e/DALTON_scratch_adrianhurtado/freq_Ne-d-aug-cc-pVDZ_214524\n\n\n DALTON: default work memory size used.            64000000\n\n Work memory size (LMWORK+2):    64000002 =  488.28 megabytes; node   0\n\n   0: Directories for basis set searches:\n     /home/adrianhurtado/testing/madness-test-suite/madness-test-suite/dalton/hf/Ne/dipole:/home/adrianhurtado/projects/dalton/build/basis\nfreq_Ne-d-aug-cc-pVDZ.tar.gz has been copied to /home/adrianhurtado/testing/madness-test-suite/madness-test-suite/dalton/hf/Ne/dipole\n----------------------------------------------------------\n1 informational messages have been issued by DALTON,\noutput from 'grep -n INFO'  (max 10 lines):\n845: INFO SIR_INTOPEN, old integral transformation not found as expected, ICASE = 2\n\n   Fri Apr 22 05:51:01 PM EDT 2022\n   ***************************************** \n" None
# {
#   "simulation": {
#     "calculations": [
#       {
#         "calculationType": "energyCalculation",
#         "calculationTime": {
#           "cpuTime": 0.012,
#           "wallTime": 0.014,
#           "units": "second"
#         },
#         "calculationResults": {
#           "totalEnergy": {
#             "value": -128.496364405682,
#             "units": "Hartree"
#           },
#           "nuclearRepulsionEnergy": {
#             "value": 0.0,
#             "units": "Hartree"
#           },
#           "electronEnergy": {
#             "value": -128.496364405682,
#             "units": "Hartree"
#           }
#         },
#         "calculationSetup": {
#           "numberOfElectrons": 10,
#           "molecularSpinMultiplicity": 1,
#           "waveFunctionType": "HF",
#           "waveFunctionTheory": "Hartree-Fock",
#           "charge": 0
#         }
#       },
#       {
#         "calculationType": "LinearResponse",
#         "calculationTime": {
#           "cpuTime": 0.01,
#           "wallTime": 0.01,
#           "units": "second"
#         },
#         "calculationResults": {
#           "xx": [
#             2.353456047067,
#             2.357760752979,
#             2.370825387562,
#             2.425480989779,
#             2.694454252133
#           ],
#           "xy": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "xz": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "yx": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "yy": [
#             2.353456047067,
#             2.357760752979,
#             2.370825387562,
#             2.425480989779,
#             2.694454252133
#           ],
#           "yz": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zx": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zy": [
#             0,
#             0,
#             0,
#             0,
#             0
#           ],
#           "zz": [
#             2.353456047067,
#             2.357760752979,
#             2.370825387562,
#             2.425480989779,
#             2.694454252133
#           ]
#         },
#         "calculationSetup": {
#           "frequencies": [
#             0.0,
#             0.04612212,
#             0.09224425,
#             0.1844885,
#             0.368977
#           ],
#           "numFrequencies": 5
#         }
#       }
#     ],
#     "simulationTime": {
#       "cpuTime": 0.05,
#       "wallTime": 0.05,
#       "units": "second"
#     }
#   }
# }
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'calculationResults'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_122459/1211857122.py in <module>
#       9 for b in basis:
#      10     g,r=drunner.getDaltonFrequencyResults('Ne','hf','dipole',b)
# ---> 11     g['calculationResults']
#      12     r['calculationResults']['xx'][0]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'calculationResults'
